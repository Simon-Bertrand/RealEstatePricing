# %%
import pandas as pd, os
from dataloader.get import DataGetter
dg=DataGetter()
df = dg.getData('train')
df_cap = pd.concat([pd.read_csv("images_captionning_results/" + f.name) for f in os.scandir("images_captionning_results")], ignore_index=True)
df_cap.rename(columns={'images': 'captions'}, inplace=True)
df_cap=df_cap.rename(columns={"index":"id_annonce"}).set_index("id_annonce")
df_cap = df_cap[~df_cap.index.duplicated(keep='first')]
df_cap.to_csv("preprocessing/data_captions.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-59e169787e3c> in <module>
#       3 dg=DataGetter()
#       4 df = dg.getData('train')
# ----> 5 df_cap = pd.concat([pd.read_csv("images_captionning_results/" + f.name) for f in os.scandir("images_captionning_results")], ignore_index=True)
#       6 df_cap.rename(columns={'images': 'captions'}, inplace=True)
#       7 df_cap=df_cap.rename(columns={"index":"id_annonce"}).set_index("id_annonce")
#
# <ipython-input-1-59e169787e3c> in <listcomp>(.0)
#       3 dg=DataGetter()
#       4 df = dg.getData('train')
# ----> 5 df_cap = pd.concat([pd.read_csv("images_captionning_results/" + f.name) for f in os.scandir("images_captionning_results")], ignore_index=True)
#       6 df_cap.rename(columns={'images': 'captions'}, inplace=True)
#       7 df_cap=df_cap.rename(columns={"index":"id_annonce"}).set_index("id_annonce")
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in __exit__(self, exc_type, exc_value, traceback)
#    1088
#    1089     def __exit__(self, exc_type, exc_value, traceback):
# -> 1090         self.close()
#    1091
#    1092
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in close(self)
#     820
#     821     def close(self):
# --> 822         self._engine.close()
#     823
#     824     def _get_options_with_defaults(self, engine):
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in close(self)
#    1986
#    1987     def close(self) -> None:
# -> 1988         super().close()
#    1989
#    1990         # close additional handles opened by C parser
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in close(self)
#    1419     def close(self):
#    1420         if self.handles is not None:
# -> 1421             self.handles.close()
#    1422
#    1423     @property
#
# c:\Users\le2fi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py in close(self)
#      93         try:
#      94             for handle in self.created_handles:
# ---> 95                 handle.close()
#      96         except (OSError, ValueError):
#      97             pass
#
# KeyboardInterrupt:

# %%
from preprocessing.utils import manageCaptions
from preprocessing.utils import makePreprocess
import pandas as pd, os
from dataloader.get import DataGetter
dg=DataGetter()
df = dg.getTrainDataWithCaptions()
df_full = makePreprocess().applyPreprocessing(df)

# %%
df_full
# Out:
#             scorePropertyType    scoreCity  scoreSize  scoreLandsize  \
# id_annonce
# 35996577             0.543463  5275.736122       63.0            0.0
# 35811033             0.543463  5268.414609       90.0            0.0
# 35731841             0.492737       4489.0       61.0          370.0
# 35886765             0.492737       4439.0      142.0          764.0
# 35781137             0.543463         5987       88.0            0.0
# ...                       ...          ...        ...            ...
# 35881571             0.543463       2013.0     2995.0            0.0
# 35890109             0.543463        10570       36.0            0.0
# 36010245             0.543463       3822.0       99.0            0.0
# 35864579             0.543463  3507.398152     9281.0            0.0
# 35748883             0.492737       1488.0       90.0          600.0
#
#             scoreFloor  scoreRoom  nb_parking_places  nb_boxes  has_a_balcony  \
# id_annonce
# 35996577      0.000000        3.0                0.0       0.0            0.0
# 35811033      1.386294        5.0                0.0       0.0            0.0
# 35731841      0.000000        2.0                0.0       0.0            0.0
# 35886765      0.000000        4.0                0.0       1.0            0.0
# 35781137      1.386294        4.0                0.0       1.0            1.0
# ...                ...        ...                ...       ...            ...
# 35881571      0.000000        1.0                0.0       0.0            0.0
# 35890109      1.609438        2.0                0.0       0.0            0.0
# 36010245      1.098612        4.0                1.0       0.0            1.0
# 35864579      0.000000        5.0                1.0       0.0            0.0
# 35748883      0.000000        4.0                0.0       0.0            0.0
#
#             nb_terraces  ...  messy  unfinished  shining  organized  huge  \
# id_annonce               ...
# 35996577            1.0  ...      0           0        0          0     0
# 35811033            0.0  ...      0           0        0          0     0
# 35731841            0.0  ...      0           0        0          0     0
# 35886765            1.0  ...      0           0        0          0     0
# 35781137            0.0  ...      0           0        0          0     0
# ...                 ...  ...    ...         ...      ...        ...   ...
# 35881571            0.0  ...      0           0        0          0     0
# 35890109            0.0  ...      0           0        0          0     0
# 36010245            0.0  ...      0           0        0          0     0
# 35864579            0.0  ...      0           0        0          0     0
# 35748883            0.0  ...      0           0        0          0     0
#
#             antique  renovated  warehouse  rooftop     price
# id_annonce
# 35996577          0          0          0        0  355000.0
# 35811033          0          0          0        0  190000.0
# 35731841          0          0          0        0   39000.0
# 35886765          0          0          0        0  299000.0
# 35781137          0          0          0        0  478000.0
# ...             ...        ...        ...      ...       ...
# 35881571          0          0          0        0  190000.0
# 35890109          0          0          0        0  399000.0
# 36010245          0          0          0        0  328000.0
# 35864579          0          0          0        0  463000.0
# 35748883          0          0          0        0   69930.0
#
# [37368 rows x 48 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b83798678ed2> in <module>
# ----> 1 makePreprocess().applyPreprocessing(df)
#
# NameError: name 'df' is not defined
