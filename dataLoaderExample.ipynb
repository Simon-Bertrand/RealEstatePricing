# %%
from dataloader.get import DataGetter

# %% [markdown]
# ### Initialisation du DataGetter

# %%
dg=DataGetter()

# %% [markdown]
# ### Chargement lazy des données (sans chargement des images)

# %%
df = dg.getData('train')

# %%
dg.getData('test')

# %% [markdown]
# Rq : pas de colonne price pour le set de test

# %% [markdown]
# ###  Chargement des données (dont les images) via itérateur

# %%
import json
from skimage import io
k=0
# id_annonce : Int
# X : pd.Series
# y : float
# images : list(np.array)
for id_annonce, X, images, y in dg.iterateLoadedData("train"):
    print(f"{k+1} - L'annonce d'identifiant : f{id_annonce} contient les valeurs : {json.dumps(X.to_dict(), indent=2)} et les images de tailles {[im.shape for im in images]} pour un prix de {y}")
    print("Affichage de la première image :")
    io.imshow(images[0])
    io.show()
    print("\n\n")
    
    k +=1
    if k>=5:break

# %%
import matplotlib.pyplot as plt
from LAVIS.get_caption import get_caption

def caption_from_image_file(x):
    return [get_caption(i) for i in x.load()]

df = dg.getData("train")
# df['captions'] = df['images'].apply(caption_from_image_file)

# %%
# Out:
#            property_type  approximate_latitude  approximate_longitude  \
# id_annonce
# 6774630      appartement             43.835987               5.786698
# 9229368      appartement             43.955761               4.811265
# 10767060          maison             47.760054              -3.347771
# 10888487     appartement             43.296752               6.630493
# 10914429          maison             43.934069               0.620489
# ...                  ...                   ...                    ...
# 36098155          maison             43.526724              -1.502224
# 36098171          maison             49.955088               1.178354
# 36098287          maison             49.315390               1.147414
# 36098743          maison             46.364387               2.490042
# 36098807          maison             43.867123               1.902733
#
#                           city  postal_code   size  floor  land_size  \
# id_annonce
# 6774630               manosque         4100   73.0    1.0        NaN
# 9229368                avignon        84000   63.0    NaN        NaN
# 10767060              lanester        56600  120.0    NaN      276.0
# 10888487         sainte-maxime        83120   94.0    NaN        NaN
# 10914429              lectoure        32700  390.0    NaN      180.0
# ...                        ...          ...    ...    ...        ...
# 36098155                boucau        64340   84.0    NaN       62.0
# 36098171    belleville-sur-mer        76370  115.0    NaN      950.0
# 36098287              igoville        27460  370.0    NaN     1933.0
# 36098743                huriel         3380   90.0    NaN       53.0
# 36098807               montans        81600  229.0    NaN      921.0
#
#             energy_performance_value energy_performance_category  ...  \
# id_annonce                                                        ...
# 6774630                        164.0                           D  ...
# 9229368                        213.0                           D  ...
# 10767060                       323.0                           E  ...
# 10888487                       152.0                           D  ...
# 10914429                         NaN                         NaN  ...
# ...                              ...                         ...  ...
# 36098155                         NaN                         NaN  ...
# 36098171                       228.0                           D  ...
# 36098287                       108.0                           C  ...
# 36098743                         NaN                         NaN  ...
# 36098807                       214.0                           D  ...
#
#             has_a_balcony nb_terraces has_a_cellar  has_a_garage  \
# id_annonce
# 6774630               0.0         0.0          1.0           1.0
# 9229368               0.0         0.0          0.0           1.0
# 10767060              0.0         0.0          0.0           1.0
# 10888487              0.0         0.0          1.0           0.0
# 10914429              1.0         0.0          1.0           0.0
# ...                   ...         ...          ...           ...
# 36098155              1.0         1.0          1.0           0.0
# 36098171              0.0         1.0          0.0           0.0
# 36098287              0.0         1.0          0.0           0.0
# 36098743              0.0         0.0          0.0           0.0
# 36098807              0.0         0.0          0.0           0.0
#
#             has_air_conditioning  last_floor  upper_floors     price  \
# id_annonce
# 6774630                      0.0         0.0           0.0  133125.0
# 9229368                      0.0         0.0           0.0   40000.0
# 10767060                     0.0         0.0           0.0  402800.0
# 10888487                     0.0         0.0           0.0  200000.0
# 10914429                     0.0         0.0           0.0  364000.0
# ...                          ...         ...           ...       ...
# 36098155                     0.0         0.0           0.0  426000.0
# 36098171                     0.0         0.0           0.0  265000.0
# 36098287                     0.0         0.0           0.0  397000.0
# 36098743                     0.0         0.0           0.0   29000.0
# 36098807                     0.0         0.0           0.0  220000.0
#
#                                        images  \
# id_annonce
# 6774630     LazyImages(len=6, isLoaded=False)
# 9229368     LazyImages(len=5, isLoaded=False)
# 10767060    LazyImages(len=6, isLoaded=False)
# 10888487    LazyImages(len=6, isLoaded=False)
# 10914429    LazyImages(len=6, isLoaded=False)
# ...                                       ...
# 36098155    LazyImages(len=3, isLoaded=False)
# 36098171    LazyImages(len=6, isLoaded=False)
# 36098287    LazyImages(len=6, isLoaded=False)
# 36098743    LazyImages(len=5, isLoaded=False)
# 36098807    LazyImages(len=6, isLoaded=False)
#
#                                                      captions
# id_annonce
# 6774630     [['a bed with a blue, green and red bedspread'...
# 9229368     [['a large bed in a small white room'], ['a ro...
# 10767060    [['a room filled with white walls and curtains...
# 10888487    [['a bathroom with a toilet, sink and a bathtu...
# 10914429    [['a blurry photo of an old fashioned bedroom'...
# ...                                                       ...
# 36098155    [['the room is full of chairs, a table and tel...
# 36098171    [['an attic apartment with large beds and furn...
# 36098287    [['a living room and dining room with large wi...
# 36098743    [['an unfinished room in an abandoned house'],...
# 36098807    [['the inside of a home bathroom with a tub an...
#
# [37569 rows x 29 columns]

# %%
len(df)
# Out:
# 37368

# %%
# Out:
# 37350

# %%
# Out:
# True
