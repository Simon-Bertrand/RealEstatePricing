# %%
from preprocessing.utils import preprocessing_score as prep
import pandas as pd

# %%
df = pd.read_csv("data/X_train_J01Z4CN.csv", index_col="id_annonce")
dfy = pd.read_csv("data/y_train_OXxrJt1.csv", index_col="id_annonce")
df['price']=dfy

# %%
Object = prep()

# %%
df
# Out:
#            property_type  approximate_latitude  approximate_longitude  \
# id_annonce
# 35996577     appartement             43.643880               7.117183
# 35811033     appartement             45.695757               4.895610
# 35731841          maison             47.966791              -1.220451
# 35886765          maison             47.289292              -1.878805
# 35781137     appartement             45.718992               4.844234
# ...                  ...                   ...                    ...
# 35881571     appartement             43.480292              -1.484324
# 35890109     appartement             48.861391               2.401158
# 36010245     appartement             44.397837              -1.164312
# 35864579          duplex             48.864204               2.808693
# 35748883          maison             46.032306               1.966711
#
#                          city  postal_code    size  floor  land_size  \
# id_annonce
# ...

# %%
df_preprocessed = Object.apply_preprocessing(df)
df_preprocessed
# Out:
#             scorePropertyType    scoreCity  scoreSize  scoreLandsize  \
# id_annonce
# 35996577             0.543463  5275.736122       63.0            0.0
# 35811033             0.543463  5268.414609       90.0            0.0
# 35731841             0.492737       4489.0       61.0          370.0
# 35886765             0.492737       4439.0      142.0          764.0
# 35781137             0.543463         5987       88.0            0.0
# ...                       ...          ...        ...            ...
# 35881571             0.543463       2013.0      299.5            0.0
# 35890109             0.543463        10570       36.0            0.0
# 36010245             0.543463       3822.0       99.0            0.0
# 35864579             0.543463  3507.398152      928.1            0.0
# 35748883             0.492737       1488.0       90.0          600.0
#
#             scoreFloor  scoreRoom  nb_parking_places  nb_boxes  has_a_balcony  \
# id_annonce
# ...
