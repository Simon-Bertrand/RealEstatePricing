# %%
import preprocessing.utils as prep
import pandas as pd

# %%
df = pd.read_csv("data/X_train_J01Z4CN.csv", index_col="id_annonce")

# %%
df.head()
# Out:
#            property_type  approximate_latitude  approximate_longitude  \
# id_annonce
# 35996577     appartement             43.643880               7.117183
# 35811033     appartement             45.695757               4.895610
# 35731841          maison             47.966791              -1.220451
# 35886765          maison             47.289292              -1.878805
# 35781137     appartement             45.718992               4.844234
#
#                          city  postal_code   size  floor  land_size  \
# id_annonce
# 35996577    villeneuve-loubet         6270   63.0    NaN        NaN
# 35811033           venissieux        69200   90.0    3.0        NaN
# 35731841             moutiers        35130   61.0    NaN      370.0
# 35886765            cordemais        44360  142.0    NaN      764.0
# 35781137            lyon-7eme        69007   88.0    3.0        NaN
#
#             energy_performance_value energy_performance_category  ...  \
# ...

# %%
prep.histogram(df,'property_type')
# Out:
# <div>                            <div id="5283295c-d618-4155-9199-11efe66bb7d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5283295c-d618-4155-9199-11efe66bb7d4")) {                    Plotly.newPlot(                        "5283295c-d618-4155-9199-11efe66bb7d4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"property_type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"appartement","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"appartement","nbinsx":100,"offsetgroup":"appartement","orientation":"v","showlegend":true,"x":["appartement","appartement","appartement","appartement","appartement","appartement","appartement","appartement","appartement","appartement","appartement","appartement","apparteme
# ...

# %%
df[df['property_type']=='maison'][['property_type','floor']].property_type.value_counts()
# Out:
# maison    15675
# Name: property_type, dtype: int64

# %%
for cols in df.columns: 
    print('cols :'df[cols].isna().sum())
# Out:
# appartement          15733
# maison               15675
# divers                2137
# terrain               1534
# villa                  781
# propriété              408
# terrain à bâtir        298
# duplex                 220
# viager                 177
# ferme                  130
# parking                 96
# loft                    54
# chalet                  48
# château                 21
# moulin                  17
# manoir                  15
# péniche                  8
# hôtel particulier        6
# chambre                  4
# gîte                     3
# atelier                  2
# hôtel                    1
# Name: property_type, dtype: int64
